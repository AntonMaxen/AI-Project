# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import h5py
import cv2
import numpy as np
import os
from pathlib import Path
from tensorflow.keras.preprocessing.image import img_to_array

# %%
root = '/content/gdrive/MyDrive/project-art/datasets/temp/train_2/'

# %%
images = []
labels = []

for name in os.listdir(root)[0:2]:
  name = 'impressionism196'

  image_path = os.path.join(root, name)
  image = cv2.imread(image_path)

  image = cv2.resize(image, (128, 128))
  image = img_to_array(image)
  images.append(image)
  labels.append()
# Out:
# /content/gdrive/MyDrive/project-art/datasets/temp/train_2/impressionism196.jpg

# %%
  from matplotlib import pyplot as plt
  plt.figure(figsize=(10,10))
  plt.imshow(np.array(image, np.int32))

# %%
# os.chdir('/')

# %%
num_images = len(images)

with h5py.File("train_2.hdf5", "w") as file:
    dataset = file.create_dataset(
        "images", np.shape(images), h5py.h5t.STD_U8BE, data=images
    )
    meta_set = file.create_dataset(
        "meta", np.shape(labels), h5py.h5t.STD_U8BE, data=labels
    )

# %%
# image = np.array(file["/images"]).astype("uint8"))
# label = int(np.array(file["/meta"]).astype("uint8"))
images_new = None
labels_new = None

with h5py.File('train_2.hdf5', 'r') as file:
    # Open the HDF5 file
    images_new = np.array(file["/images"]).astype("uint8")
    labels_new = np.array(file["/meta"]).astype("uint8")

# %%
from PIL import Image

from matplotlib import pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(images_new[0])
